# %%
import os
os.environ["SM_FRAMEWORK"] = "tf.keras"

from tensorflow import keras
from segmentation_models import Unet, Linknet, PSPNet, FPN
# Out:
# 2024-02-22 09:57:19.378207: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-22 09:57:19.404973: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-22 09:57:19.555898: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-22 09:57:19.555964: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-22 09:57:19.578853: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-22 09:57:19.636252: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-22 09:57:19.637664: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-22 09:57:20.644412: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Segmentation Models: using `tf.keras` framework.

# %%
import os
import cv2
import numpy as np

# Specify the folder path containing TIFF images
tiff_folder = './Images/CEA2_MEB'
image_filename = "Image_4_01.tif"
image_path = os.path.join(tiff_folder, image_filename)

image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
if len(image.shape) == 2:
    image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

import matplotlib.pyplot as plt
plt.imshow(image,cmap='gray')

# %%
model = PSPNet('resnet34', encoder_weights='imagenet')
model.summary
# Out:
# <bound method Model.summary of <keras.src.engine.functional.Functional object at 0x7fcdf4662f50>>

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  data (InputLayer)           [(None, 384, 384, 3)]        0         []
#
#  bn_data (BatchNormalizatio  (None, 384, 384, 3)          9         ['data[0][0]']
#  n)
#
#  zero_padding2d (ZeroPaddin  (None, 390, 390, 3)          0         ['bn_data[0][0]']
#  g2D)
#
#  conv0 (Conv2D)              (None, 192, 192, 64)         9408      ['zero_padding2d[0][0]']
#
#  bn0 (BatchNormalization)    (None, 192, 192, 64)         256       ['conv0[0][0]']
#
#  relu0 (Activation)          (None, 192, 192, 64)         0         ['bn0[0][0]']
#
#  zero_padding2d_1 (ZeroPadd  (None, 194, 194, 64)         0         ['relu0[0][0]']
#  ing2D)
#
#  pooling0 (MaxPooling2D)     (None, 96, 96, 64)           0         ['zero_padding2d_1[0][0]']
#
#  stage1_unit1_bn1 (BatchNor  (None, 96, 96, 64)           256       ['pooling0[0][0]']
#  malization)
#
#  stage1_unit1_relu1 (Activa  (None, 96, 96, 64)           0         ['stage1_unit1_bn1[0][0]']
#  tion)
#
#  zero_padding2d_2 (ZeroPadd  (None, 98, 98, 64)           0         ['stage1_unit1_relu1[0][0]']
#  ing2D)
#
#  stage1_unit1_conv1 (Conv2D  (None, 96, 96, 64)           36864     ['zero_padding2d_2[0][0]']
#  )
#
#  stage1_unit1_bn2 (BatchNor  (None, 96, 96, 64)           256       ['stage1_unit1_conv1[0][0]']
#  malization)
#
#  stage1_unit1_relu2 (Activa  (None, 96, 96, 64)           0         ['stage1_unit1_bn2[0][0]']
#  tion)
#
#  zero_padding2d_3 (ZeroPadd  (None, 98, 98, 64)           0         ['stage1_unit1_relu2[0][0]']
#  ing2D)
#
#  stage1_unit1_conv2 (Conv2D  (None, 96, 96, 64)           36864     ['zero_padding2d_3[0][0]']
#  )
#
#  stage1_unit1_sc (Conv2D)    (None, 96, 96, 64)           4096      ['stage1_unit1_relu1[0][0]']
#
#  add (Add)                   (None, 96, 96, 64)           0         ['stage1_unit1_conv2[0][0]',
#                                                                      'stage1_unit1_sc[0][0]']
#
#  stage1_unit2_bn1 (BatchNor  (None, 96, 96, 64)           256       ['add[0][0]']
#  malization)
#
#  stage1_unit2_relu1 (Activa  (None, 96, 96, 64)           0         ['stage1_unit2_bn1[0][0]']
#  tion)
#
#  zero_padding2d_4 (ZeroPadd  (None, 98, 98, 64)           0         ['stage1_unit2_relu1[0][0]']
#  ing2D)
#
#  stage1_unit2_conv1 (Conv2D  (None, 96, 96, 64)           36864     ['zero_padding2d_4[0][0]']
#  )
#
#  stage1_unit2_bn2 (BatchNor  (None, 96, 96, 64)           256       ['stage1_unit2_conv1[0][0]']
#  malization)
#
#  stage1_unit2_relu2 (Activa  (None, 96, 96, 64)           0         ['stage1_unit2_bn2[0][0]']
#  tion)
#
#  zero_padding2d_5 (ZeroPadd  (None, 98, 98, 64)           0         ['stage1_unit2_relu2[0][0]']
#  ing2D)
#
#  stage1_unit2_conv2 (Conv2D  (None, 96, 96, 64)           36864     ['zero_padding2d_5[0][0]']
#  )
#
#  add_1 (Add)                 (None, 96, 96, 64)           0         ['stage1_unit2_conv2[0][0]',
#                                                                      'add[0][0]']
#
#  stage1_unit3_bn1 (BatchNor  (None, 96, 96, 64)           256       ['add_1[0][0]']
#  malization)
#
#  stage1_unit3_relu1 (Activa  (None, 96, 96, 64)           0         ['stage1_unit3_bn1[0][0]']
#  tion)
#
#  zero_padding2d_6 (ZeroPadd  (None, 98, 98, 64)           0         ['stage1_unit3_relu1[0][0]']
#  ing2D)
#
#  stage1_unit3_conv1 (Conv2D  (None, 96, 96, 64)           36864     ['zero_padding2d_6[0][0]']
#  )
#
#  stage1_unit3_bn2 (BatchNor  (None, 96, 96, 64)           256       ['stage1_unit3_conv1[0][0]']
#  malization)
#
#  stage1_unit3_relu2 (Activa  (None, 96, 96, 64)           0         ['stage1_unit3_bn2[0][0]']
#  tion)
#
#  zero_padding2d_7 (ZeroPadd  (None, 98, 98, 64)           0         ['stage1_unit3_relu2[0][0]']
#  ing2D)
#
#  stage1_unit3_conv2 (Conv2D  (None, 96, 96, 64)           36864     ['zero_padding2d_7[0][0]']
#  )
#
#  add_2 (Add)                 (None, 96, 96, 64)           0         ['stage1_unit3_conv2[0][0]',
#                                                                      'add_1[0][0]']
#
#  stage2_unit1_bn1 (BatchNor  (None, 96, 96, 64)           256       ['add_2[0][0]']
#  malization)
#
#  stage2_unit1_relu1 (Activa  (None, 96, 96, 64)           0         ['stage2_unit1_bn1[0][0]']
#  tion)
#
#  zero_padding2d_8 (ZeroPadd  (None, 98, 98, 64)           0         ['stage2_unit1_relu1[0][0]']
#  ing2D)
#
#  stage2_unit1_conv1 (Conv2D  (None, 48, 48, 128)          73728     ['zero_padding2d_8[0][0]']
#  )
#
#  stage2_unit1_bn2 (BatchNor  (None, 48, 48, 128)          512       ['stage2_unit1_conv1[0][0]']
#  malization)
#
#  stage2_unit1_relu2 (Activa  (None, 48, 48, 128)          0         ['stage2_unit1_bn2[0][0]']
#  tion)
#
#  zero_padding2d_9 (ZeroPadd  (None, 50, 50, 128)          0         ['stage2_unit1_relu2[0][0]']
#  ing2D)
#
#  stage2_unit1_conv2 (Conv2D  (None, 48, 48, 128)          147456    ['zero_padding2d_9[0][0]']
#  )
#
#  stage2_unit1_sc (Conv2D)    (None, 48, 48, 128)          8192      ['stage2_unit1_relu1[0][0]']
#
#  add_3 (Add)                 (None, 48, 48, 128)          0         ['stage2_unit1_conv2[0][0]',
#                                                                      'stage2_unit1_sc[0][0]']
#
#  stage2_unit2_bn1 (BatchNor  (None, 48, 48, 128)          512       ['add_3[0][0]']
#  malization)
#
#  stage2_unit2_relu1 (Activa  (None, 48, 48, 128)          0         ['stage2_unit2_bn1[0][0]']
#  tion)
#
#  zero_padding2d_10 (ZeroPad  (None, 50, 50, 128)          0         ['stage2_unit2_relu1[0][0]']
#  ding2D)
#
#  stage2_unit2_conv1 (Conv2D  (None, 48, 48, 128)          147456    ['zero_padding2d_10[0][0]']
#  )
#
#  stage2_unit2_bn2 (BatchNor  (None, 48, 48, 128)          512       ['stage2_unit2_conv1[0][0]']
#  malization)
#
#  stage2_unit2_relu2 (Activa  (None, 48, 48, 128)          0         ['stage2_unit2_bn2[0][0]']
#  tion)
#
#  zero_padding2d_11 (ZeroPad  (None, 50, 50, 128)          0         ['stage2_unit2_relu2[0][0]']
#  ding2D)
#
#  stage2_unit2_conv2 (Conv2D  (None, 48, 48, 128)          147456    ['zero_padding2d_11[0][0]']
#  )
#
#  add_4 (Add)                 (None, 48, 48, 128)          0         ['stage2_unit2_conv2[0][0]',
#                                                                      'add_3[0][0]']
#
#  stage2_unit3_bn1 (BatchNor  (None, 48, 48, 128)          512       ['add_4[0][0]']
#  malization)
#
#  stage2_unit3_relu1 (Activa  (None, 48, 48, 128)          0         ['stage2_unit3_bn1[0][0]']
#  tion)
#
#  zero_padding2d_12 (ZeroPad  (None, 50, 50, 128)          0         ['stage2_unit3_relu1[0][0]']
#  ding2D)
#
#  stage2_unit3_conv1 (Conv2D  (None, 48, 48, 128)          147456    ['zero_padding2d_12[0][0]']
#  )
#
#  stage2_unit3_bn2 (BatchNor  (None, 48, 48, 128)          512       ['stage2_unit3_conv1[0][0]']
#  malization)
#
#  stage2_unit3_relu2 (Activa  (None, 48, 48, 128)          0         ['stage2_unit3_bn2[0][0]']
#  tion)
#
#  zero_padding2d_13 (ZeroPad  (None, 50, 50, 128)          0         ['stage2_unit3_relu2[0][0]']
#  ding2D)
#
#  stage2_unit3_conv2 (Conv2D  (None, 48, 48, 128)          147456    ['zero_padding2d_13[0][0]']
#  )
#
#  add_5 (Add)                 (None, 48, 48, 128)          0         ['stage2_unit3_conv2[0][0]',
#                                                                      'add_4[0][0]']
#
#  stage2_unit4_bn1 (BatchNor  (None, 48, 48, 128)          512       ['add_5[0][0]']
#  malization)
#
#  stage2_unit4_relu1 (Activa  (None, 48, 48, 128)          0         ['stage2_unit4_bn1[0][0]']
#  tion)
#
#  zero_padding2d_14 (ZeroPad  (None, 50, 50, 128)          0         ['stage2_unit4_relu1[0][0]']
#  ding2D)
#
#  stage2_unit4_conv1 (Conv2D  (None, 48, 48, 128)          147456    ['zero_padding2d_14[0][0]']
#  )
#
#  stage2_unit4_bn2 (BatchNor  (None, 48, 48, 128)          512       ['stage2_unit4_conv1[0][0]']
#  malization)
#
#  stage2_unit4_relu2 (Activa  (None, 48, 48, 128)          0         ['stage2_unit4_bn2[0][0]']
#  tion)
#
#  zero_padding2d_15 (ZeroPad  (None, 50, 50, 128)          0         ['stage2_unit4_relu2[0][0]']
#  ding2D)
#
#  stage2_unit4_conv2 (Conv2D  (None, 48, 48, 128)          147456    ['zero_padding2d_15[0][0]']
#  )
#
#  add_6 (Add)                 (None, 48, 48, 128)          0         ['stage2_unit4_conv2[0][0]',
#                                                                      'add_5[0][0]']
#
#  stage3_unit1_bn1 (BatchNor  (None, 48, 48, 128)          512       ['add_6[0][0]']
#  malization)
#
#  stage3_unit1_relu1 (Activa  (None, 48, 48, 128)          0         ['stage3_unit1_bn1[0][0]']
#  tion)
#
#  psp_level1_pooling (Averag  (None, 1, 1, 128)            0         ['stage3_unit1_relu1[0][0]']
#  ePooling2D)
#
#  psp_level2_pooling (Averag  (None, 2, 2, 128)            0         ['stage3_unit1_relu1[0][0]']
#  ePooling2D)
#
#  psp_level3_pooling (Averag  (None, 3, 3, 128)            0         ['stage3_unit1_relu1[0][0]']
#  ePooling2D)
#
#  psp_level6_pooling (Averag  (None, 6, 6, 128)            0         ['stage3_unit1_relu1[0][0]']
#  ePooling2D)
#
#  psp_level1_conv (Conv2D)    (None, 1, 1, 512)            65536     ['psp_level1_pooling[0][0]']
#
#  psp_level2_conv (Conv2D)    (None, 2, 2, 512)            65536     ['psp_level2_pooling[0][0]']
#
#  psp_level3_conv (Conv2D)    (None, 3, 3, 512)            65536     ['psp_level3_pooling[0][0]']
#
#  psp_level6_conv (Conv2D)    (None, 6, 6, 512)            65536     ['psp_level6_pooling[0][0]']
#
#  psp_level1_bn (BatchNormal  (None, 1, 1, 512)            2048      ['psp_level1_conv[0][0]']
#  ization)
#
#  psp_level2_bn (BatchNormal  (None, 2, 2, 512)            2048      ['psp_level2_conv[0][0]']
#  ization)
#
#  psp_level3_bn (BatchNormal  (None, 3, 3, 512)            2048      ['psp_level3_conv[0][0]']
#  ization)
#
#  psp_level6_bn (BatchNormal  (None, 6, 6, 512)            2048      ['psp_level6_conv[0][0]']
#  ization)
#
#  psp_level1_relu (Activatio  (None, 1, 1, 512)            0         ['psp_level1_bn[0][0]']
#  n)
#
#  psp_level2_relu (Activatio  (None, 2, 2, 512)            0         ['psp_level2_bn[0][0]']
#  n)
#
#  psp_level3_relu (Activatio  (None, 3, 3, 512)            0         ['psp_level3_bn[0][0]']
#  n)
#
#  psp_level6_relu (Activatio  (None, 6, 6, 512)            0         ['psp_level6_bn[0][0]']
#  n)
#
#  psp_level1_upsampling (UpS  (None, 48, 48, 512)          0         ['psp_level1_relu[0][0]']
#  ampling2D)
#
#  psp_level2_upsampling (UpS  (None, 48, 48, 512)          0         ['psp_level2_relu[0][0]']
#  ampling2D)
#
#  psp_level3_upsampling (UpS  (None, 48, 48, 512)          0         ['psp_level3_relu[0][0]']
#  ampling2D)
#
#  psp_level6_upsampling (UpS  (None, 48, 48, 512)          0         ['psp_level6_relu[0][0]']
#  ampling2D)
#
#  psp_concat (Concatenate)    (None, 48, 48, 2176)         0         ['stage3_unit1_relu1[0][0]',
#                                                                      'psp_level1_upsampling[0][0]'
#                                                                     , 'psp_level2_upsampling[0][0]
#                                                                     ',
#                                                                      'psp_level3_upsampling[0][0]'
#                                                                     , 'psp_level6_upsampling[0][0]
#                                                                     ']
#
#  aggregation_conv (Conv2D)   (None, 48, 48, 512)          1114112   ['psp_concat[0][0]']
#
#  aggregation_bn (BatchNorma  (None, 48, 48, 512)          2048      ['aggregation_conv[0][0]']
#  lization)
#
#  aggregation_relu (Activati  (None, 48, 48, 512)          0         ['aggregation_bn[0][0]']
#  on)
#
#  final_conv (Conv2D)         (None, 48, 48, 21)           96789     ['aggregation_relu[0][0]']
#
#  final_upsampling (UpSampli  (None, 384, 384, 21)         0         ['final_conv[0][0]']
#  ng2D)
#
#  softmax (Activation)        (None, 384, 384, 21)         0         ['final_upsampling[0][0]']
#
# ==================================================================================================
# Total params: 2838238 (10.83 MB)
# Trainable params: 2830040 (10.80 MB)
# Non-trainable params: 8198 (32.02 KB)
# __________________________________________________________________________________________________

# %%
print(image.shape)
# Out:
# (1024, 1280, 3)

# %%
im = cv2.resize(image,(384, 384))
im = im.reshape(1, 384,384, 3)
print(im.shape)
segmented = model.predict(im)
# Out:
# (1, 384, 384, 3)
# 1/1 [==============================] - 0s 428ms/step

# %%
import matplotlib.pyplot as plt 
plt.imshow(image)

# %%
segmented.shape
# segmented is a 21 channel image, which can be used to segment the image.
# Out:
# (1, 384, 384, 21)

# %%
from sklearn.cluster import MiniBatchKMeans
print(segmented.shape)
# segment the image into 2 clusters : foreground and background
clustering = MiniBatchKMeans(n_clusters=2)
yes_no = clustering.fit_predict(segmented.reshape(-1,21))
# Out:
# (1, 384, 384, 21)

# %%
yes_no = yes_no.reshape(384,384,1)
plt.imshow(yes_no)
